# %%
import ete3
import pandas as pd
from pprint import pprint
import numpy as np

# %%
def annotate_lineages(tree, gnmdf, col):
    for leaf in tree.get_leaves():
        sp = list(leaf.get_species())[0]
        feat_val = list(gnmdf[col][gnmdf['Proteome'] == sp])[0]
        leaf.add_feature(col, feat_val)

    return 0

# %%
def clade_norm(tree, tree_id, cladedf, col):
    annotate_lineages(tree, cladedf, col)
    tlno = len(tree.get_leaf_names())

    mphysets = list()
    for st in tree.traverse():
        leaves = st.get_leaves()

        feat_list = list()
        for stleag in st.get_leaves():
            feat_list.append(getattr(stleag, col))

        if (len(set(feat_list)) == 1 and len(leaves) > 1 and
                len(leaves) != tlno):
            mphy = dict()
            mphy['tree'] = tree_id
            mphy['node'] = st
            mphy['seq_no'] = len(leaves)
            mphy[col] = feat_list[0]
            mphysets.append(mphy)

    nodedf = pd.DataFrame(mphysets)
    indexes = nodedf.index
    
    mphylist = list()
    for group in set(nodedf[col]):
        if str(group) != 'nan':
            maxval = max(nodedf.loc[nodedf[col] == group]['seq_no'])
            dfindex = indexes[(nodedf[col] == group) & (nodedf['seq_no'] == maxval)]
            mphylist.append(mphysets[dfindex.values[0]])
    
    nodel = list()
    for nodedict in mphylist:
        nodel.append(norm_factor(nodedict))

    return nodel

# %%
def get_species(node):
    if '_' in node:
        return node.split("_")[1]
    else:
        return node

# %%
def norm_factor(nodedict):
    ndlf = nodedict['node'].get_leaves()
    distl = list()
    for leaf in ndlf:
        distl.append(nodedict['node'].get_distance(leaf))
    nodedict['mrca_to_tip_median'] = np.median(distl)
    
    return nodedict

# %%
tree = ete3.PhyloTree('../data/0005_sptree.nwk', sp_naming_function=get_species)

# %%
gnmdf = pd.read_csv('../data/0005_norm_groups.csv')
gnmdf.columns
# Out:
# Index(['Proteome', 'TaxaID', 'Date', 'Longest', 'Source', 'Species Name',
#        'Normalising group'],
#       dtype='object')

# %%
cladesl = list()
for line in open('../data/0005_19.txt', 'r'):
    tree = ete3.PhyloTree(line.split('\t')[3], sp_naming_function=get_species)
    cladesl += clade_norm(tree, line.split('\t')[0], gnmdf, 'Normalising group')

# %%
cladedf = pd.DataFrame(cladesl)
cladedf = cladedf.set_index('tree')
normfactor = cladedf[cladedf['Normalising group'] == 'B'].mrca_to_tip_median
# Out:
# tree
# Phy000CWI8_YEAST    0.170794
# Phy000CXDB_YEAST    0.257514
# Phy000CWKW_YEAST    0.438460
# Phy000CY3M_YEAST    0.271640
# Phy000CXWU_YEAST    0.429059
#                       ...
# Phy000CYSF_YEAST    0.023830
# Phy000CYMZ_YEAST    0.215596
# Phy000CZP0_YEAST    0.821982
# Phy000CXUN_YEAST    0.803219
# Phy000CXY3_YEAST    0.070789
# Name: mrca_to_tip_median, Length: 208, dtype: float64

# %%
# Out:
# [{'Normalising group': 'B',
#   'mrca_to_tip_median': 0.170794,
#   'node': PhyloTree node '' (0x7f18eebadc4),
#   'seq_no': 12,
#   'tree': 'Phy000CWI8_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.13262100000000002,
#   'node': PhyloTree node '' (0x7f18eebad8b),
#   'seq_no': 9,
#   'tree': 'Phy000CWI8_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.2575145,
#   'node': PhyloTree node '' (0x7f18eebb63d),
#   'seq_no': 10,
#   'tree': 'Phy000CXDB_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3078785,
#   'node': PhyloTree node '' (0x7f18eebb625),
#   'seq_no': 4,
#   'tree': 'Phy000CXDB_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.43846,
#   'node': PhyloTree node '' (0x7f18eebc90a),
#   'seq_no': 121,
#   'tree': 'Phy000CWKW_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.36852999999999997,
#   'node': PhyloTree node '' (0x7f18eebb679),
#   'seq_no': 24,
#   'tree': 'Phy000CWKW_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.27164,
#   'node': PhyloTree node '' (0x7f18eeb8e0d),
#   'seq_no': 12,
#   'tree': 'Phy000CY3M_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.187954,
#   'node': PhyloTree node '' (0x7f18f013385),
#   'seq_no': 4,
#   'tree': 'Phy000CY3M_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4290595,
#   'node': PhyloTree node '' (0x7f18eeb8e64),
#   'seq_no': 16,
#   'tree': 'Phy000CXWU_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2723005,
#   'node': PhyloTree node '' (0x7f18eeb8e8e),
#   'seq_no': 2,
#   'tree': 'Phy000CXWU_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.394734,
#   'node': PhyloTree node '' (0x7f18eeb2104),
#   'seq_no': 12,
#   'tree': 'Phy000CVWD_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.206857,
#   'node': PhyloTree node '' (0x7f18eeb213d),
#   'seq_no': 4,
#   'tree': 'Phy000CVWD_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.258747,
#   'node': PhyloTree node '' (0x7f18eeb218e),
#   'seq_no': 10,
#   'tree': 'Phy000CYER_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5759485,
#   'node': PhyloTree node '' (0x7f18eeb21b5),
#   'seq_no': 10,
#   'tree': 'Phy000CVKB_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.4036915000000003,
#   'node': PhyloTree node '' (0x7f18eeb2e49),
#   'seq_no': 16,
#   'tree': 'Phy000CWKF_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.448979,
#   'node': PhyloTree node '' (0x7f18eeb40d3),
#   'seq_no': 17,
#   'tree': 'Phy000D074_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.8769640000000001,
#   'node': PhyloTree node '' (0x7f18eeb2eeb),
#   'seq_no': 15,
#   'tree': 'Phy000D074_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.28286,
#   'node': PhyloTree node '' (0x7f18eeb50c1),
#   'seq_no': 13,
#   'tree': 'Phy000CVK8_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.25061100000000003,
#   'node': PhyloTree node '' (0x7f18eeaee2b),
#   'seq_no': 2,
#   'tree': 'Phy000CVK8_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.322337,
#   'node': PhyloTree node '' (0x7f18eeaee64),
#   'seq_no': 3,
#   'tree': 'Phy000CZJN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.604069,
#   'node': PhyloTree node '' (0x7f18eeafc43),
#   'seq_no': 19,
#   'tree': 'Phy000CVYK_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5813535000000001,
#   'node': PhyloTree node '' (0x7f18eeaeedc),
#   'seq_no': 16,
#   'tree': 'Phy000CVYK_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.521569,
#   'node': PhyloTree node '' (0x7f18eeb1510),
#   'seq_no': 6,
#   'tree': 'Phy000CWOS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.21314299999999997,
#   'node': PhyloTree node '' (0x7f18eeaa285),
#   'seq_no': 16,
#   'tree': 'Phy000CYZX_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.29017550000000003,
#   'node': PhyloTree node '' (0x7f18eeb159d),
#   'seq_no': 8,
#   'tree': 'Phy000CYZX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.723562,
#   'node': PhyloTree node '' (0x7f18eea6b58),
#   'seq_no': 20,
#   'tree': 'Phy000D044_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.468561,
#   'node': PhyloTree node '' (0x7f18eea6b37),
#   'seq_no': 8,
#   'tree': 'Phy000D044_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.538636,
#   'node': PhyloTree node '' (0x7f18eea7c19),
#   'seq_no': 13,
#   'tree': 'Phy000CZ05_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.276855,
#   'node': PhyloTree node '' (0x7f18eea6be8),
#   'seq_no': 4,
#   'tree': 'Phy000CZ05_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.21126,
#   'node': PhyloTree node '' (0x7f18eea7c94),
#   'seq_no': 3,
#   'tree': 'Phy000CZJ1_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.47283650000000005,
#   'node': PhyloTree node '' (0x7f18eea7c97),
#   'seq_no': 12,
#   'tree': 'Phy000CXO9_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.247062,
#   'node': PhyloTree node '' (0x7f18eea7cc7),
#   'seq_no': 2,
#   'tree': 'Phy000CXO9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.33297699999999997,
#   'node': PhyloTree node '' (0x7f18eea987c),
#   'seq_no': 20,
#   'tree': 'Phy000CXZV_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3560745,
#   'node': PhyloTree node '' (0x7f18eea8e73),
#   'seq_no': 8,
#   'tree': 'Phy000CXZV_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.3909230000000001,
#   'node': PhyloTree node '' (0x7f18eea3cb8),
#   'seq_no': 15,
#   'tree': 'Phy000CXY9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.876027,
#   'node': PhyloTree node '' (0x7f18ee9e049),
#   'seq_no': 9,
#   'tree': 'Phy000CYIN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.43908800000000003,
#   'node': PhyloTree node '' (0x7f18ee9e08b),
#   'seq_no': 12,
#   'tree': 'Phy000CZD2_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.063255,
#   'node': PhyloTree node '' (0x7f18ee9e0ca),
#   'seq_no': 7,
#   'tree': 'Phy000CZD2_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.432561,
#   'node': PhyloTree node '' (0x7f18ee9ed88),
#   'seq_no': 12,
#   'tree': 'Phy000CXIX_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.41593600000000003,
#   'node': PhyloTree node '' (0x7f18ee9eda6),
#   'seq_no': 4,
#   'tree': 'Phy000CXIX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.465047,
#   'node': PhyloTree node '' (0x7f18ee9ed6d),
#   'seq_no': 11,
#   'tree': 'Phy000CZIR_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.583103,
#   'node': PhyloTree node '' (0x7f18ee9edee),
#   'seq_no': 3,
#   'tree': 'Phy000CZIR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.115619,
#   'node': PhyloTree node '' (0x7f18eea01e2),
#   'seq_no': 12,
#   'tree': 'Phy000CZ7N_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.4399965,
#   'node': PhyloTree node '' (0x7f18eea10af),
#   'seq_no': 8,
#   'tree': 'Phy000CZ7N_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4331195,
#   'node': PhyloTree node '' (0x7f18ee9a0f4),
#   'seq_no': 12,
#   'tree': 'Phy000CZN0_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.33101,
#   'node': PhyloTree node '' (0x7f18ee9c10a),
#   'seq_no': 4,
#   'tree': 'Phy000CZN0_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.657165,
#   'node': PhyloTree node '' (0x7f18ee9c158),
#   'seq_no': 7,
#   'tree': 'Phy000CWOX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6597360000000001,
#   'node': PhyloTree node '' (0x7f18ee9c191),
#   'seq_no': 12,
#   'tree': 'Phy000CYAG_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.41320350000000006,
#   'node': PhyloTree node '' (0x7f18ee9cd5e),
#   'seq_no': 8,
#   'tree': 'Phy000CYAG_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.334806,
#   'node': PhyloTree node '' (0x7f18ee9cde5),
#   'seq_no': 12,
#   'tree': 'Phy000CW8M_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.40469700000000003,
#   'node': PhyloTree node '' (0x7f18ee9cdf7),
#   'seq_no': 7,
#   'tree': 'Phy000CW8M_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5707985,
#   'node': PhyloTree node '' (0x7f18ee96249),
#   'seq_no': 12,
#   'tree': 'Phy000CWWE_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.365634,
#   'node': PhyloTree node '' (0x7f18ee96282),
#   'seq_no': 3,
#   'tree': 'Phy000CWWE_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.356851,
#   'node': PhyloTree node '' (0x7f18ee962c7),
#   'seq_no': 6,
#   'tree': 'Phy000CWD1_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.978779,
#   'node': PhyloTree node '' (0x7f18ee962fa),
#   'seq_no': 2,
#   'tree': 'Phy000CWD1_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.164742,
#   'node': PhyloTree node '' (0x7f18ee98649),
#   'seq_no': 13,
#   'tree': 'Phy000CVMT_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.15733999999999998,
#   'node': PhyloTree node '' (0x7f18ee98691),
#   'seq_no': 8,
#   'tree': 'Phy000CVMT_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.902449,
#   'node': PhyloTree node '' (0x7f18ee986cd),
#   'seq_no': 21,
#   'tree': 'Phy000CW9K_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.567133,
#   'node': PhyloTree node '' (0x7f18ee92391),
#   'seq_no': 19,
#   'tree': 'Phy000CZSF_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.383122,
#   'node': PhyloTree node '' (0x7f18ee923e2),
#   'seq_no': 3,
#   'tree': 'Phy000CZSF_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.035988000000000006,
#   'node': PhyloTree node '' (0x7f18ee9369a),
#   'seq_no': 13,
#   'tree': 'Phy000CYCG_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1587155,
#   'node': PhyloTree node '' (0x7f18ee94213),
#   'seq_no': 8,
#   'tree': 'Phy000CYCG_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.30754299999999996,
#   'node': PhyloTree node '' (0x7f18ee8fa07),
#   'seq_no': 19,
#   'tree': 'Phy000CXS3_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3591365000000001,
#   'node': PhyloTree node '' (0x7f18ee8e988),
#   'seq_no': 14,
#   'tree': 'Phy000CXS3_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.3697515,
#   'node': PhyloTree node '' (0x7f18ee8adfa),
#   'seq_no': 12,
#   'tree': 'Phy000CX6T_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.45007050000000004,
#   'node': PhyloTree node '' (0x7f18ee8add3),
#   'seq_no': 8,
#   'tree': 'Phy000CX6T_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.507217,
#   'node': PhyloTree node '' (0x7f18ee8b658),
#   'seq_no': 14,
#   'tree': 'Phy000CZAR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.40026799999999996,
#   'node': PhyloTree node '' (0x7f18ee8d507),
#   'seq_no': 12,
#   'tree': 'Phy000CWZA_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.27321150000000005,
#   'node': PhyloTree node '' (0x7f18ee8b6f4),
#   'seq_no': 4,
#   'tree': 'Phy000CWZA_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5855425,
#   'node': PhyloTree node '' (0x7f18ee8d594),
#   'seq_no': 12,
#   'tree': 'Phy000CXFM_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.44369749999999997,
#   'node': PhyloTree node '' (0x7f18ee8d58b),
#   'seq_no': 4,
#   'tree': 'Phy000CXFM_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.401393,
#   'node': PhyloTree node '' (0x7f18ee8d5df),
#   'seq_no': 9,
#   'tree': 'Phy000CZES_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.1645465,
#   'node': PhyloTree node '' (0x7f18ee86419),
#   'seq_no': 12,
#   'tree': 'Phy000D0L1_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.294985,
#   'node': PhyloTree node '' (0x7f18ee86425),
#   'seq_no': 7,
#   'tree': 'Phy000D0L1_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6360445,
#   'node': PhyloTree node '' (0x7f18ee87a04),
#   'seq_no': 12,
#   'tree': 'Phy000CZ5S_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.406599,
#   'node': PhyloTree node '' (0x7f18ee87a0d),
#   'seq_no': 3,
#   'tree': 'Phy000CZ5S_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.578406,
#   'node': PhyloTree node '' (0x7f18ee87a8e),
#   'seq_no': 12,
#   'tree': 'Phy000CY5U_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.685249,
#   'node': PhyloTree node '' (0x7f18ee87ad6),
#   'seq_no': 3,
#   'tree': 'Phy000CY5U_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.329069,
#   'node': PhyloTree node '' (0x7f18ee88e88),
#   'seq_no': 18,
#   'tree': 'Phy000CZ4F_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5554045,
#   'node': PhyloTree node '' (0x7f18ee81c64),
#   'seq_no': 8,
#   'tree': 'Phy000CZ4F_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.424443,
#   'node': PhyloTree node '' (0x7f18ee83fee),
#   'seq_no': 12,
#   'tree': 'Phy000CYRL_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5032129999999999,
#   'node': PhyloTree node '' (0x7f18ee83fd9),
#   'seq_no': 8,
#   'tree': 'Phy000CYRL_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4728505,
#   'node': PhyloTree node '' (0x7f18ee7e485),
#   'seq_no': 12,
#   'tree': 'Phy000D03Y_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2489005,
#   'node': PhyloTree node '' (0x7f18ee7e48b),
#   'seq_no': 4,
#   'tree': 'Phy000D03Y_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7173060000000001,
#   'node': PhyloTree node '' (0x7f18ee7e4ca),
#   'seq_no': 11,
#   'tree': 'Phy000CYQ9_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.355086,
#   'node': PhyloTree node '' (0x7f18ee7e4ee),
#   'seq_no': 3,
#   'tree': 'Phy000CYQ9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.956267,
#   'node': PhyloTree node '' (0x7f18ee7f576),
#   'seq_no': 61,
#   'tree': 'Phy000D089_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.676024,
#   'node': PhyloTree node '' (0x7f18ee7a882),
#   'seq_no': 12,
#   'tree': 'Phy000CW17_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.656054,
#   'node': PhyloTree node '' (0x7f18ee800fa),
#   'seq_no': 16,
#   'tree': 'Phy000CW17_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4628895,
#   'node': PhyloTree node '' (0x7f18ee7c855),
#   'seq_no': 12,
#   'tree': 'Phy000CWSB_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.385717,
#   'node': PhyloTree node '' (0x7f18ee76f25),
#   'seq_no': 19,
#   'tree': 'Phy000CWW6_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.384866,
#   'node': PhyloTree node '' (0x7f18ee7c8c7),
#   'seq_no': 8,
#   'tree': 'Phy000CWW6_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.08635899999999999,
#   'node': PhyloTree node '' (0x7f18ee777f7),
#   'seq_no': 15,
#   'tree': 'Phy000CWOP_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.086138,
#   'node': PhyloTree node '' (0x7f18ee72167),
#   'seq_no': 17,
#   'tree': 'Phy000CYVJ_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.017472,
#   'node': PhyloTree node '' (0x7f18ee7212b),
#   'seq_no': 8,
#   'tree': 'Phy000CYVJ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4375,
#   'node': PhyloTree node '' (0x7f18ee730e2),
#   'seq_no': 13,
#   'tree': 'Phy000CXMK_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3019775,
#   'node': PhyloTree node '' (0x7f18ee7309d),
#   'seq_no': 8,
#   'tree': 'Phy000CXMK_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7300335,
#   'node': PhyloTree node '' (0x7f18ee74c76),
#   'seq_no': 8,
#   'tree': 'Phy000CX48_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.290336,
#   'node': PhyloTree node '' (0x7f18ee74ca3),
#   'seq_no': 5,
#   'tree': 'Phy000CX48_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6869449999999999,
#   'node': PhyloTree node '' (0x7f18ee74cfa),
#   'seq_no': 25,
#   'tree': 'Phy000D02Q_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.3961085,
#   'node': PhyloTree node '' (0x7f18ee700d3),
#   'seq_no': 20,
#   'tree': 'Phy000CY24_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.39169050000000005,
#   'node': PhyloTree node '' (0x7f18ee6f143),
#   'seq_no': 8,
#   'tree': 'Phy000CY24_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.321348,
#   'node': PhyloTree node '' (0x7f18ee6ba10),
#   'seq_no': 13,
#   'tree': 'Phy000CXVB_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.37572149999999993,
#   'node': PhyloTree node '' (0x7f18ee6c5e2),
#   'seq_no': 8,
#   'tree': 'Phy000CYPR_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.7687065,
#   'node': PhyloTree node '' (0x7f18ee6c54f),
#   'seq_no': 16,
#   'tree': 'Phy000CYPR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.341252,
#   'node': PhyloTree node '' (0x7f18ee6cdf7),
#   'seq_no': 14,
#   'tree': 'Phy000CXM2_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.685712,
#   'node': PhyloTree node '' (0x7f18ee6cd31),
#   'seq_no': 19,
#   'tree': 'Phy000CXM2_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.744349,
#   'node': PhyloTree node '' (0x7f18ee665a6),
#   'seq_no': 7,
#   'tree': 'Phy000CZ9E_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.038066,
#   'node': PhyloTree node '' (0x7f18ee665c4),
#   'seq_no': 5,
#   'tree': 'Phy000CWM6_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.167857,
#   'node': PhyloTree node '' (0x7f18ee665b5),
#   'seq_no': 8,
#   'tree': 'Phy000CWM6_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5779565,
#   'node': PhyloTree node '' (0x7f18ee67d43),
#   'seq_no': 12,
#   'tree': 'Phy000CZKA_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.385989,
#   'node': PhyloTree node '' (0x7f18ee67d7f),
#   'seq_no': 4,
#   'tree': 'Phy000CZKA_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.062159,
#   'node': PhyloTree node '' (0x7f18ee67db8),
#   'seq_no': 17,
#   'tree': 'Phy000CXEW_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.0293365,
#   'node': PhyloTree node '' (0x7f18ee67de2),
#   'seq_no': 2,
#   'tree': 'Phy000CXEW_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7595719999999999,
#   'node': PhyloTree node '' (0x7f18ee68e79),
#   'seq_no': 18,
#   'tree': 'Phy000CWQ4_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.8519939999999999,
#   'node': PhyloTree node '' (0x7f18ee68ed6),
#   'seq_no': 12,
#   'tree': 'Phy000CWQ4_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.267816,
#   'node': PhyloTree node '' (0x7f18ee621a3),
#   'seq_no': 11,
#   'tree': 'Phy000CVJW_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.08980550000000001,
#   'node': PhyloTree node '' (0x7f18ee621d0),
#   'seq_no': 2,
#   'tree': 'Phy000CVJW_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7907675000000001,
#   'node': PhyloTree node '' (0x7f18ee6376d),
#   'seq_no': 6,
#   'tree': 'Phy000CVOV_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.0781695,
#   'node': PhyloTree node '' (0x7f18ee637ac),
#   'seq_no': 12,
#   'tree': 'Phy000CVZX_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.8589985,
#   'node': PhyloTree node '' (0x7f18ee637cd),
#   'seq_no': 2,
#   'tree': 'Phy000CVZX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.49683400000000005,
#   'node': PhyloTree node '' (0x7f18ee5dcc7),
#   'seq_no': 67,
#   'tree': 'Phy000CXFS_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5980359999999999,
#   'node': PhyloTree node '' (0x7f18ee5dc6d),
#   'seq_no': 18,
#   'tree': 'Phy000CXFS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.320502,
#   'node': PhyloTree node '' (0x7f18ee5fe79),
#   'seq_no': 12,
#   'tree': 'Phy000CW2R_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2675815,
#   'node': PhyloTree node '' (0x7f18ee5feac),
#   'seq_no': 2,
#   'tree': 'Phy000CW2R_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4005875,
#   'node': PhyloTree node '' (0x7f18ee5a519),
#   'seq_no': 12,
#   'tree': 'Phy000CYET_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2560395,
#   'node': PhyloTree node '' (0x7f18ee5fef4),
#   'seq_no': 4,
#   'tree': 'Phy000CYET_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.371099,
#   'node': PhyloTree node '' (0x7f18ee5a579),
#   'seq_no': 7,
#   'tree': 'Phy000CX7J_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.488718,
#   'node': PhyloTree node '' (0x7f18ee5b370),
#   'seq_no': 41,
#   'tree': 'Phy000CXHN_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5929855,
#   'node': PhyloTree node '' (0x7f18ee5bc61),
#   'seq_no': 66,
#   'tree': 'Phy000CXHN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7378475000000001,
#   'node': PhyloTree node '' (0x7f18ee55f4c),
#   'seq_no': 12,
#   'tree': 'Phy000CXBN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.099138,
#   'node': PhyloTree node '' (0x7f18ee51e73),
#   'seq_no': 13,
#   'tree': 'Phy000CXFC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.439287,
#   'node': PhyloTree node '' (0x7f18ee55fca),
#   'seq_no': 8,
#   'tree': 'Phy000CXFC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.691277,
#   'node': PhyloTree node '' (0x7f18ee54534),
#   'seq_no': 12,
#   'tree': 'Phy000CVX9_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.4297255,
#   'node': PhyloTree node '' (0x7f18ee5450d),
#   'seq_no': 8,
#   'tree': 'Phy000CVX9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.817252,
#   'node': PhyloTree node '' (0x7f18ee545b2),
#   'seq_no': 7,
#   'tree': 'Phy000CZN3_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.300642,
#   'node': PhyloTree node '' (0x7f18ee545c7),
#   'seq_no': 5,
#   'tree': 'Phy000CXAX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8032519999999999,
#   'node': PhyloTree node '' (0x7f18ee545d9),
#   'seq_no': 10,
#   'tree': 'Phy000CXQ9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.113748,
#   'node': PhyloTree node '' (0x7f18ee55458),
#   'seq_no': 9,
#   'tree': 'Phy000CYI3_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.10228200000000001,
#   'node': PhyloTree node '' (0x7f18ee55449),
#   'seq_no': 3,
#   'tree': 'Phy000CYI3_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.208629,
#   'node': PhyloTree node '' (0x7f18ee55461),
#   'seq_no': 7,
#   'tree': 'Phy000CXBH_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.855264,
#   'node': PhyloTree node '' (0x7f18ee554c4),
#   'seq_no': 27,
#   'tree': 'Phy000NLTD_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6841275,
#   'node': PhyloTree node '' (0x7f18ee4e5a3),
#   'seq_no': 12,
#   'tree': 'Phy000D0I6_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5666785000000001,
#   'node': PhyloTree node '' (0x7f18ee4e5cd),
#   'seq_no': 2,
#   'tree': 'Phy000D0I6_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8463495,
#   'node': PhyloTree node '' (0x7f18ee4f610),
#   'seq_no': 6,
#   'tree': 'Phy000D02D_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.28218499999999996,
#   'node': PhyloTree node '' (0x7f18ee4f652),
#   'seq_no': 8,
#   'tree': 'Phy000D02D_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.130717,
#   'node': PhyloTree node '' (0x7f18ee4f6b8),
#   'seq_no': 5,
#   'tree': 'Phy000CWYS_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.245877,
#   'node': PhyloTree node '' (0x7f18ee4f6d9),
#   'seq_no': 7,
#   'tree': 'Phy000CWYS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.35743,
#   'node': PhyloTree node '' (0x7f18ee50aa0),
#   'seq_no': 12,
#   'tree': 'Phy000CXEV_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5911775,
#   'node': PhyloTree node '' (0x7f18ee50adc),
#   'seq_no': 8,
#   'tree': 'Phy000CXEV_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7252409999999999,
#   'node': PhyloTree node '' (0x7f18ee5192b),
#   'seq_no': 13,
#   'tree': 'Phy000CX0V_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.42515650000000005,
#   'node': PhyloTree node '' (0x7f18ee519a6),
#   'seq_no': 10,
#   'tree': 'Phy000CZFI_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.253739,
#   'node': PhyloTree node '' (0x7f18ee519dc),
#   'seq_no': 3,
#   'tree': 'Phy000CZFI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.195452,
#   'node': PhyloTree node '' (0x7f18ee4633d),
#   'seq_no': 13,
#   'tree': 'Phy000CYUN_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2665045,
#   'node': PhyloTree node '' (0x7f18ee4b0b2),
#   'seq_no': 8,
#   'tree': 'Phy000CYUN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4946735,
#   'node': PhyloTree node '' (0x7f18ee463d6),
#   'seq_no': 10,
#   'tree': 'Phy000CX8M_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.29612299999999997,
#   'node': PhyloTree node '' (0x7f18ee463f1),
#   'seq_no': 5,
#   'tree': 'Phy000CX8M_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.0,
#   'node': PhyloTree node '' (0x7f18ee48931),
#   'seq_no': 4,
#   'tree': 'Phy000CX7A_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.05384599999999999,
#   'node': PhyloTree node '' (0x7f18ee4323a),
#   'seq_no': 17,
#   'tree': 'Phy000D01D_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.28300949999999997,
#   'node': PhyloTree node '' (0x7f18ee42297),
#   'seq_no': 8,
#   'tree': 'Phy000D01D_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5216605,
#   'node': PhyloTree node '' (0x7f18ee3db28),
#   'seq_no': 12,
#   'tree': 'Phy000CZ03_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.303234,
#   'node': PhyloTree node '' (0x7f18ee3db73),
#   'seq_no': 8,
#   'tree': 'Phy000CZ03_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.42036599999999996,
#   'node': PhyloTree node '' (0x7f18ee3f049),
#   'seq_no': 13,
#   'tree': 'Phy000CVOF_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.770802,
#   'node': PhyloTree node '' (0x7f18ee3f0b2),
#   'seq_no': 11,
#   'tree': 'Phy000D0JS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.16263299999999997,
#   'node': PhyloTree node '' (0x7f18ee40d4c),
#   'seq_no': 11,
#   'tree': 'Phy000CVJI_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1293425,
#   'node': PhyloTree node '' (0x7f18ee40d2b),
#   'seq_no': 8,
#   'tree': 'Phy000CVJI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.1653015,
#   'node': PhyloTree node '' (0x7f18ee3a194),
#   'seq_no': 12,
#   'tree': 'Phy000CYSR_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.15672100000000003,
#   'node': PhyloTree node '' (0x7f18ee3a158),
#   'seq_no': 8,
#   'tree': 'Phy000CYSR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.38885200000000003,
#   'node': PhyloTree node '' (0x7f18ee3c4a9),
#   'seq_no': 21,
#   'tree': 'Phy000CVJY_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.20952900000000002,
#   'node': PhyloTree node '' (0x7f18ee3aed9),
#   'seq_no': 8,
#   'tree': 'Phy000CVJY_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.338804,
#   'node': PhyloTree node '' (0x7f18ee3768e),
#   'seq_no': 19,
#   'tree': 'Phy000CW1D_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.218049,
#   'node': PhyloTree node '' (0x7f18ee37667),
#   'seq_no': 8,
#   'tree': 'Phy000CW1D_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.21408850000000001,
#   'node': PhyloTree node '' (0x7f18ee393d9),
#   'seq_no': 12,
#   'tree': 'Phy000CY6O_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1920025,
#   'node': PhyloTree node '' (0x7f18ee37e40),
#   'seq_no': 8,
#   'tree': 'Phy000CY6O_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 2.412036,
#   'node': PhyloTree node '' (0x7f18ee335be),
#   'seq_no': 70,
#   'tree': 'Phy000CVYC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.707452,
#   'node': PhyloTree node '' (0x7f18ee2e188),
#   'seq_no': 12,
#   'tree': 'Phy000CY70_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.560033,
#   'node': PhyloTree node '' (0x7f18ee2e16a),
#   'seq_no': 8,
#   'tree': 'Phy000CY70_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8569239999999999,
#   'node': PhyloTree node '' (0x7f18ee2f8cd),
#   'seq_no': 29,
#   'tree': 'Phy000CW9Y_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.45125899999999997,
#   'node': PhyloTree node '' (0x7f18ee2f89d),
#   'seq_no': 17,
#   'tree': 'Phy000CW9Y_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4418405,
#   'node': PhyloTree node '' (0x7f18ee2c119),
#   'seq_no': 12,
#   'tree': 'Phy000CZGC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 1.644739,
#   'node': PhyloTree node '' (0x7f18ee2c167),
#   'seq_no': 8,
#   'tree': 'Phy000CZGC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.4300180000000002,
#   'node': PhyloTree node '' (0x7f18ee2d031),
#   'seq_no': 11,
#   'tree': 'Phy000CY7I_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.350392,
#   'node': PhyloTree node '' (0x7f18ee2d0fd),
#   'seq_no': 12,
#   'tree': 'Phy000D047_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.506826,
#   'node': PhyloTree node '' (0x7f18ee2743d),
#   'seq_no': 9,
#   'tree': 'Phy000D047_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9846060000000001,
#   'node': PhyloTree node '' (0x7f18ee2747c),
#   'seq_no': 17,
#   'tree': 'Phy000CXO5_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.24595599999999998,
#   'node': PhyloTree node '' (0x7f18ee28749),
#   'seq_no': 2,
#   'tree': 'Phy000CZBT_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.4330095,
#   'node': PhyloTree node '' (0x7f18ee28734),
#   'seq_no': 6,
#   'tree': 'Phy000CZBT_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6773155,
#   'node': PhyloTree node '' (0x7f18f01406d),
#   'seq_no': 12,
#   'tree': 'Phy000D005_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5382105,
#   'node': PhyloTree node '' (0x7f18f0141d9),
#   'seq_no': 4,
#   'tree': 'Phy000D005_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7887405000000001,
#   'node': PhyloTree node '' (0x7f18f013d1c),
#   'seq_no': 18,
#   'tree': 'Phy000CYKS_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.600105,
#   'node': PhyloTree node '' (0x7f18f0139bb),
#   'seq_no': 2,
#   'tree': 'Phy000CYKS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.176017,
#   'node': PhyloTree node '' (0x7f18f013813),
#   'seq_no': 12,
#   'tree': 'Phy000CXN3_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.215215,
#   'node': PhyloTree node '' (0x7f18f013697),
#   'seq_no': 2,
#   'tree': 'Phy000CXN3_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7312305,
#   'node': PhyloTree node '' (0x7f18f01330a),
#   'seq_no': 12,
#   'tree': 'Phy000D0FC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.876366,
#   'node': PhyloTree node '' (0x7f18f013373),
#   'seq_no': 3,
#   'tree': 'Phy000D0FC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.280661,
#   'node': PhyloTree node '' (0x7f18ef80b9d),
#   'seq_no': 3,
#   'tree': 'Phy000CYJG_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2338125,
#   'node': PhyloTree node '' (0x7f18f013143),
#   'seq_no': 8,
#   'tree': 'Phy000CYJG_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.24519200000000002,
#   'node': PhyloTree node '' (0x7f18ef7d9c4),
#   'seq_no': 13,
#   'tree': 'Phy000CXFK_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.187079,
#   'node': PhyloTree node '' (0x7f18ef7d6ac),
#   'seq_no': 3,
#   'tree': 'Phy000CXFK_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.885851,
#   'node': PhyloTree node '' (0x7f18f011b43),
#   'seq_no': 11,
#   'tree': 'Phy000CWLO_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.37118850000000003,
#   'node': PhyloTree node '' (0x7f18f01ccb8),
#   'seq_no': 24,
#   'tree': 'Phy000CX1E_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.645018,
#   'node': PhyloTree node '' (0x7f18f017f04),
#   'seq_no': 32,
#   'tree': 'Phy000CX1E_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.516538,
#   'node': PhyloTree node '' (0x7f18f01cc64),
#   'seq_no': 11,
#   'tree': 'Phy000CZ5P_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.25818050000000003,
#   'node': PhyloTree node '' (0x7f18f01cc13),
#   'seq_no': 4,
#   'tree': 'Phy000CZ5P_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.865473,
#   'node': PhyloTree node '' (0x7f18f058da0),
#   'seq_no': 9,
#   'tree': 'Phy000D0B5_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.48802999999999996,
#   'node': PhyloTree node '' (0x7f18f0569b2),
#   'seq_no': 12,
#   'tree': 'Phy000CZQF_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.251417,
#   'node': PhyloTree node '' (0x7f18f056976),
#   'seq_no': 8,
#   'tree': 'Phy000CZQF_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.082236,
#   'node': PhyloTree node '' (0x7f18ef7a6f7),
#   'seq_no': 11,
#   'tree': 'Phy000CWNA_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.40490899999999996,
#   'node': PhyloTree node '' (0x7f18ef7d8af),
#   'seq_no': 3,
#   'tree': 'Phy000CWNA_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.44725650000000006,
#   'node': PhyloTree node '' (0x7f18ef7da9a),
#   'seq_no': 10,
#   'tree': 'Phy000CXLS_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.682431,
#   'node': PhyloTree node '' (0x7f18ef7d846),
#   'seq_no': 8,
#   'tree': 'Phy000CXLS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.214455,
#   'node': PhyloTree node '' (0x7f18f19be43),
#   'seq_no': 12,
#   'tree': 'Phy000CWZT_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.15167799999999998,
#   'node': PhyloTree node '' (0x7f18ee28767),
#   'seq_no': 8,
#   'tree': 'Phy000CWZT_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.36950299999999997,
#   'node': PhyloTree node '' (0x7f18f1d7c2e),
#   'seq_no': 3,
#   'tree': 'Phy000CY7G_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 1.09731,
#   'node': PhyloTree node '' (0x7f18ee287f4),
#   'seq_no': 35,
#   'tree': 'Phy000CY7G_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.421119,
#   'node': PhyloTree node '' (0x7f18f1d710d),
#   'seq_no': 12,
#   'tree': 'Phy000CWTF_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.22074500000000002,
#   'node': PhyloTree node '' (0x7f18f1d7191),
#   'seq_no': 4,
#   'tree': 'Phy000CW04_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.060491,
#   'node': PhyloTree node '' (0x7f18f1d71e2),
#   'seq_no': 5,
#   'tree': 'Phy000CW4P_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.4439765,
#   'node': PhyloTree node '' (0x7f18f1d7179),
#   'seq_no': 8,
#   'tree': 'Phy000CW4P_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8271220000000001,
#   'node': PhyloTree node '' (0x7f18f1d6d5e),
#   'seq_no': 5,
#   'tree': 'Phy000CZ6V_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9588669999999999,
#   'node': PhyloTree node '' (0x7f18f1d6d79),
#   'seq_no': 12,
#   'tree': 'Phy000CZ6Z_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.754928,
#   'node': PhyloTree node '' (0x7f18f1d804c),
#   'seq_no': 13,
#   'tree': 'Phy000CW8X_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.726055,
#   'node': PhyloTree node '' (0x7f18f1d6da9),
#   'seq_no': 7,
#   'tree': 'Phy000CW8X_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.477133,
#   'node': PhyloTree node '' (0x7f18f0967fa),
#   'seq_no': 10,
#   'tree': 'Phy000CX5Z_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.705031,
#   'node': PhyloTree node '' (0x7f18f1d80cd),
#   'seq_no': 7,
#   'tree': 'Phy000CX5Z_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.38750949999999995,
#   'node': PhyloTree node '' (0x7f18f09677c),
#   'seq_no': 24,
#   'tree': 'Phy000CW3L_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.365698,
#   'node': PhyloTree node '' (0x7f18f0982ac),
#   'seq_no': 15,
#   'tree': 'Phy000CW3L_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.1668915,
#   'node': PhyloTree node '' (0x7f18f098bd0),
#   'seq_no': 12,
#   'tree': 'Phy000D00X_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2618315,
#   'node': PhyloTree node '' (0x7f18f098ba0),
#   'seq_no': 8,
#   'tree': 'Phy000D00X_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.660455,
#   'node': PhyloTree node '' (0x7f18f096d94),
#   'seq_no': 11,
#   'tree': 'Phy000CZFC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.4782555,
#   'node': PhyloTree node '' (0x7f18f096d4c),
#   'seq_no': 8,
#   'tree': 'Phy000CZFC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8330919999999999,
#   'node': PhyloTree node '' (0x7f18f0a6f6d),
#   'seq_no': 9,
#   'tree': 'Phy000CZ8P_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.222098,
#   'node': PhyloTree node '' (0x7f18f0a6f9a),
#   'seq_no': 6,
#   'tree': 'Phy000CX5S_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.147534,
#   'node': PhyloTree node '' (0x7f18f0a941f),
#   'seq_no': 3,
#   'tree': 'Phy000CX5S_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.15539999999999998,
#   'node': PhyloTree node '' (0x7f18f0a7073),
#   'seq_no': 36,
#   'tree': 'Phy000CY86_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3448415,
#   'node': PhyloTree node '' (0x7f18f0a94e5),
#   'seq_no': 8,
#   'tree': 'Phy000CY86_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.438311,
#   'node': PhyloTree node '' (0x7f18f079b67),
#   'seq_no': 12,
#   'tree': 'Phy000CXTN_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.10467549999999999,
#   'node': PhyloTree node '' (0x7f18f079b25),
#   'seq_no': 8,
#   'tree': 'Phy000CXTN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.236313,
#   'node': PhyloTree node '' (0x7f18f234ec7),
#   'seq_no': 20,
#   'tree': 'Phy000CZQ4_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.34159300000000004,
#   'node': PhyloTree node '' (0x7f18f234e22),
#   'seq_no': 8,
#   'tree': 'Phy000CZQ4_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5761474999999999,
#   'node': PhyloTree node '' (0x7f18f234fc7),
#   'seq_no': 20,
#   'tree': 'Phy000CYPO_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.6259319999999999,
#   'node': PhyloTree node '' (0x7f18f1c813a),
#   'seq_no': 9,
#   'tree': 'Phy000CYPO_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.156451,
#   'node': PhyloTree node '' (0x7f18f1c81ee),
#   'seq_no': 15,
#   'tree': 'Phy000CVJQ_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.0874675,
#   'node': PhyloTree node '' (0x7f18f1c81e2),
#   'seq_no': 8,
#   'tree': 'Phy000CVJQ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.316844,
#   'node': PhyloTree node '' (0x7f18f1c7aaf),
#   'seq_no': 9,
#   'tree': 'Phy000CYIX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.40123050000000005,
#   'node': PhyloTree node '' (0x7f18f1c6655),
#   'seq_no': 12,
#   'tree': 'Phy000CXCX_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3810365,
#   'node': PhyloTree node '' (0x7f18f1c6697),
#   'seq_no': 14,
#   'tree': 'Phy000CXCX_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8953255,
#   'node': PhyloTree node '' (0x7f18f1c8a28),
#   'seq_no': 12,
#   'tree': 'Phy000CY9K_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.6451505,
#   'node': PhyloTree node '' (0x7f18f1c8a04),
#   'seq_no': 8,
#   'tree': 'Phy000CY9K_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.46107599999999993,
#   'node': PhyloTree node '' (0x7f18f22a8b8),
#   'seq_no': 12,
#   'tree': 'Phy000CWCL_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.48225699999999994,
#   'node': PhyloTree node '' (0x7f18f03e9c4),
#   'seq_no': 8,
#   'tree': 'Phy000CWCL_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.1270665,
#   'node': PhyloTree node '' (0x7f18f22bc67),
#   'seq_no': 10,
#   'tree': 'Phy000CX5T_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.145844,
#   'node': PhyloTree node '' (0x7f18f22bcf7),
#   'seq_no': 9,
#   'tree': 'Phy000CZRY_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.272084,
#   'node': PhyloTree node '' (0x7f18f22bca6),
#   'seq_no': 7,
#   'tree': 'Phy000CZRY_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7464660000000001,
#   'node': PhyloTree node '' (0x7f18f22a19d),
#   'seq_no': 12,
#   'tree': 'Phy000D0JC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.56053,
#   'node': PhyloTree node '' (0x7f18f22a194),
#   'seq_no': 4,
#   'tree': 'Phy000D0JC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.347621,
#   'node': PhyloTree node '' (0x7f18f22af0a),
#   'seq_no': 12,
#   'tree': 'Phy000CYVC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.444682,
#   'node': PhyloTree node '' (0x7f18f22a1eb),
#   'seq_no': 8,
#   'tree': 'Phy000CYVC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.183633,
#   'node': PhyloTree node '' (0x7f18f22af85),
#   'seq_no': 9,
#   'tree': 'Phy000CVRH_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.218043,
#   'node': PhyloTree node '' (0x7f18f219046),
#   'seq_no': 17,
#   'tree': 'Phy000CYDC_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.26144599999999996,
#   'node': PhyloTree node '' (0x7f18f216825),
#   'seq_no': 8,
#   'tree': 'Phy000CYDC_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.22232200000000002,
#   'node': PhyloTree node '' (0x7f18f1fdd3d),
#   'seq_no': 18,
#   'tree': 'Phy000CZ6O_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.223682,
#   'node': PhyloTree node '' (0x7f18f1fdd10),
#   'seq_no': 9,
#   'tree': 'Phy000CZ6O_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4396045,
#   'node': PhyloTree node '' (0x7f18f1eef76),
#   'seq_no': 20,
#   'tree': 'Phy000D02Y_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5334260000000001,
#   'node': PhyloTree node '' (0x7f18f1eef04),
#   'seq_no': 10,
#   'tree': 'Phy000D02Y_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.350303,
#   'node': PhyloTree node '' (0x7f18f1ef449),
#   'seq_no': 19,
#   'tree': 'Phy000NLTS_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.7346455,
#   'node': PhyloTree node '' (0x7f18f1efd28),
#   'seq_no': 8,
#   'tree': 'Phy000NLTS_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.3730989999999998,
#   'node': PhyloTree node '' (0x7f18f0ab122),
#   'seq_no': 21,
#   'tree': 'Phy000CZS8_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.437766,
#   'node': PhyloTree node '' (0x7f18f0ab1c7),
#   'seq_no': 12,
#   'tree': 'Phy000D03P_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5737935,
#   'node': PhyloTree node '' (0x7f18f0ab1df),
#   'seq_no': 2,
#   'tree': 'Phy000D03P_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.908725,
#   'node': PhyloTree node '' (0x7f18f0aa767),
#   'seq_no': 12,
#   'tree': 'Phy000CVR1_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.396754,
#   'node': PhyloTree node '' (0x7f18f0aa73d),
#   'seq_no': 7,
#   'tree': 'Phy000CVR1_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.535085,
#   'node': PhyloTree node '' (0x7f18f0aa7c1),
#   'seq_no': 13,
#   'tree': 'Phy000CW73_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.341125,
#   'node': PhyloTree node '' (0x7f18f0aa7f7),
#   'seq_no': 4,
#   'tree': 'Phy000CW73_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 2.3728979999999997,
#   'node': PhyloTree node '' (0x7f18f0ada61),
#   'seq_no': 112,
#   'tree': 'Phy000CVZT_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.7047080000000001,
#   'node': PhyloTree node '' (0x7f18f1da6c1),
#   'seq_no': 10,
#   'tree': 'Phy000CXHQ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.1175734999999998,
#   'node': PhyloTree node '' (0x7f18f1d9e94),
#   'seq_no': 50,
#   'tree': 'Phy000CVR8_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.673461,
#   'node': PhyloTree node '' (0x7f18f27621c),
#   'seq_no': 13,
#   'tree': 'Phy000CVR8_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5043314999999999,
#   'node': PhyloTree node '' (0x7f18f277da9),
#   'seq_no': 12,
#   'tree': 'Phy000CZ7D_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.5854914999999999,
#   'node': PhyloTree node '' (0x7f18f277d82),
#   'seq_no': 8,
#   'tree': 'Phy000CZ7D_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9668654999999999,
#   'node': PhyloTree node '' (0x7f18f276c2e),
#   'seq_no': 8,
#   'tree': 'Phy000CZJU_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.956267,
#   'node': PhyloTree node '' (0x7f18f276c7f),
#   'seq_no': 61,
#   'tree': 'Phy000CZ3O_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9377185,
#   'node': PhyloTree node '' (0x7f18f158dd6),
#   'seq_no': 12,
#   'tree': 'Phy000CX0G_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.2847365,
#   'node': PhyloTree node '' (0x7f18f158dfd),
#   'seq_no': 2,
#   'tree': 'Phy000CX0G_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.7754414999999999,
#   'node': PhyloTree node '' (0x7f18f15777f),
#   'seq_no': 12,
#   'tree': 'Phy000CW82_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.80449,
#   'node': PhyloTree node '' (0x7f18f157767),
#   'seq_no': 7,
#   'tree': 'Phy000CW82_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9419980000000001,
#   'node': PhyloTree node '' (0x7f18f219d1f),
#   'seq_no': 17,
#   'tree': 'Phy000D0J8_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.801151,
#   'node': PhyloTree node '' (0x7f18f158b13),
#   'seq_no': 8,
#   'tree': 'Phy000D0J8_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.847595,
#   'node': PhyloTree node '' (0x7f18f21d1a3),
#   'seq_no': 12,
#   'tree': 'Phy000CX9L_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3545605,
#   'node': PhyloTree node '' (0x7f18f21d1b5),
#   'seq_no': 2,
#   'tree': 'Phy000CX9L_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.334708,
#   'node': PhyloTree node '' (0x7f18f21d1f1),
#   'seq_no': 12,
#   'tree': 'Phy000CVWR_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.181458,
#   'node': PhyloTree node '' (0x7f18f21d1c7),
#   'seq_no': 2,
#   'tree': 'Phy000CVWR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.3360805,
#   'node': PhyloTree node '' (0x7f18f083b73),
#   'seq_no': 124,
#   'tree': 'Phy000D07L_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.217016,
#   'node': PhyloTree node '' (0x7f18f082b0d),
#   'seq_no': 3,
#   'tree': 'Phy000CWPU_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.40539650000000005,
#   'node': PhyloTree node '' (0x7f18f082bb5),
#   'seq_no': 8,
#   'tree': 'Phy000CWPU_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.552764,
#   'node': PhyloTree node '' (0x7f18f06403a),
#   'seq_no': 12,
#   'tree': 'Phy000CW8E_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.175766,
#   'node': PhyloTree node '' (0x7f18f082b5e),
#   'seq_no': 8,
#   'tree': 'Phy000CW8E_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.12641449999999999,
#   'node': PhyloTree node '' (0x7f18f06583a),
#   'seq_no': 18,
#   'tree': 'Phy000CY88_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.040853,
#   'node': PhyloTree node '' (0x7f18f065873),
#   'seq_no': 3,
#   'tree': 'Phy000CY88_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5053585,
#   'node': PhyloTree node '' (0x7f18f0658f4),
#   'seq_no': 12,
#   'tree': 'Phy000CZT1_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.24975200000000003,
#   'node': PhyloTree node '' (0x7f18f061b3d),
#   'seq_no': 3,
#   'tree': 'Phy000CZT1_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.60619,
#   'node': PhyloTree node '' (0x7f18f061b5e),
#   'seq_no': 11,
#   'tree': 'Phy000CYB0_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.37219250000000004,
#   'node': PhyloTree node '' (0x7f18f061b6a),
#   'seq_no': 4,
#   'tree': 'Phy000CYB0_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.016746,
#   'node': PhyloTree node '' (0x7f18f064abb),
#   'seq_no': 37,
#   'tree': 'Phy000CWL2_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.810532,
#   'node': PhyloTree node '' (0x7f18f0627a0),
#   'seq_no': 15,
#   'tree': 'Phy000CWL2_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.30797,
#   'node': PhyloTree node '' (0x7f18f02e746),
#   'seq_no': 11,
#   'tree': 'Phy000CVSI_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.32454,
#   'node': PhyloTree node '' (0x7f18f02e73a),
#   'seq_no': 3,
#   'tree': 'Phy000CVSI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.087996,
#   'node': PhyloTree node '' (0x7f18f02e75b),
#   'seq_no': 6,
#   'tree': 'Phy000CZMI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6587775,
#   'node': PhyloTree node '' (0x7f18f02e7e8),
#   'seq_no': 12,
#   'tree': 'Phy000CXHZ_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.245492,
#   'node': PhyloTree node '' (0x7f18f031337),
#   'seq_no': 2,
#   'tree': 'Phy000CXHZ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.123038,
#   'node': PhyloTree node '' (0x7f18f02f949),
#   'seq_no': 13,
#   'tree': 'Phy000CZZD_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1647255,
#   'node': PhyloTree node '' (0x7f18f031358),
#   'seq_no': 8,
#   'tree': 'Phy000CZZD_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.2853905,
#   'node': PhyloTree node '' (0x7f18f02d013),
#   'seq_no': 12,
#   'tree': 'Phy000CZLM_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.167742,
#   'node': PhyloTree node '' (0x7f18f02f9ca),
#   'seq_no': 8,
#   'tree': 'Phy000CZLM_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.294531,
#   'node': PhyloTree node '' (0x7f18f02d09a),
#   'seq_no': 6,
#   'tree': 'Phy000NLTB_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.115812,
#   'node': PhyloTree node '' (0x7f18f02b428),
#   'seq_no': 12,
#   'tree': 'Phy000CVZU_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1242415,
#   'node': PhyloTree node '' (0x7f18f02d0f7),
#   'seq_no': 8,
#   'tree': 'Phy000CVZU_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.15603,
#   'node': PhyloTree node '' (0x7f18f14e7a6),
#   'seq_no': 13,
#   'tree': 'Phy000CXWT_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.07934349999999998,
#   'node': PhyloTree node '' (0x7f18f14e782),
#   'seq_no': 8,
#   'tree': 'Phy000CXWT_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.078949,
#   'node': PhyloTree node '' (0x7f18f151334),
#   'seq_no': 25,
#   'tree': 'Phy000CX7M_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.091269,
#   'node': PhyloTree node '' (0x7f18f15134c),
#   'seq_no': 3,
#   'tree': 'Phy000CX7M_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.5524384999999999,
#   'node': PhyloTree node '' (0x7f18f1513be),
#   'seq_no': 12,
#   'tree': 'Phy000CZPI_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.514845,
#   'node': PhyloTree node '' (0x7f18f1ea12b),
#   'seq_no': 8,
#   'tree': 'Phy000CZPI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.27675400000000006,
#   'node': PhyloTree node '' (0x7f18f1ea1f1),
#   'seq_no': 11,
#   'tree': 'Phy000CYSM_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.273559,
#   'node': PhyloTree node '' (0x7f18f1ecd07),
#   'seq_no': 4,
#   'tree': 'Phy000CYSM_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.337013,
#   'node': PhyloTree node '' (0x7f18f1ecd31),
#   'seq_no': 12,
#   'tree': 'Phy000CZ42_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.24655200000000002,
#   'node': PhyloTree node '' (0x7f18f1ea40d),
#   'seq_no': 18,
#   'tree': 'Phy000CZZ4_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.19340849999999998,
#   'node': PhyloTree node '' (0x7f18f1ecde5),
#   'seq_no': 8,
#   'tree': 'Phy000CZZ4_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.9978140000000001,
#   'node': PhyloTree node '' (0x7f18f1ea49d),
#   'seq_no': 11,
#   'tree': 'Phy000CWEZ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.4260005,
#   'node': PhyloTree node '' (0x7f18f1ebf2e),
#   'seq_no': 8,
#   'tree': 'Phy000CXEG_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.3997945,
#   'node': PhyloTree node '' (0x7f18f1ebf8b),
#   'seq_no': 20,
#   'tree': 'Phy000CW2V_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.24291300000000002,
#   'node': PhyloTree node '' (0x7f18f1ebf1c),
#   'seq_no': 8,
#   'tree': 'Phy000CW2V_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.6335945,
#   'node': PhyloTree node '' (0x7f18f08c59d),
#   'seq_no': 20,
#   'tree': 'Phy000CXME_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.235512,
#   'node': PhyloTree node '' (0x7f18f08c576),
#   'seq_no': 8,
#   'tree': 'Phy000CXME_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.942742,
#   'node': PhyloTree node '' (0x7f18f089b58),
#   'seq_no': 13,
#   'tree': 'Phy000CZCI_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.7512490000000001,
#   'node': PhyloTree node '' (0x7f18f089b94),
#   'seq_no': 4,
#   'tree': 'Phy000CZCI_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.44235,
#   'node': PhyloTree node '' (0x7f18f08d637),
#   'seq_no': 10,
#   'tree': 'Phy000CYS9_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.242562,
#   'node': PhyloTree node '' (0x7f18f08d607),
#   'seq_no': 9,
#   'tree': 'Phy000CYS9_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.667522,
#   'node': PhyloTree node '' (0x7f18f08d682),
#   'seq_no': 17,
#   'tree': 'Phy000CX33_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.3261325,
#   'node': PhyloTree node '' (0x7f18f059682),
#   'seq_no': 8,
#   'tree': 'Phy000CX33_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.232947,
#   'node': PhyloTree node '' (0x7f18f056a25),
#   'seq_no': 10,
#   'tree': 'Phy000CX0Y_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.240555,
#   'node': PhyloTree node '' (0x7f18f056a58),
#   'seq_no': 3,
#   'tree': 'Phy000CX0Y_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.3256245,
#   'node': PhyloTree node '' (0x7f18f202855),
#   'seq_no': 18,
#   'tree': 'Phy000CZKL_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.149551,
#   'node': PhyloTree node '' (0x7f18f20282e),
#   'seq_no': 8,
#   'tree': 'Phy000CZKL_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.1559075,
#   'node': PhyloTree node '' (0x7f18f205885),
#   'seq_no': 12,
#   'tree': 'Phy000CX0I_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1549505,
#   'node': PhyloTree node '' (0x7f18f205861),
#   'seq_no': 8,
#   'tree': 'Phy000CX0I_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.21215499999999998,
#   'node': PhyloTree node '' (0x7f18f2058fd),
#   'seq_no': 13,
#   'tree': 'Phy000D0C0_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.235051,
#   'node': PhyloTree node '' (0x7f18f1fad43),
#   'seq_no': 8,
#   'tree': 'Phy000D0C0_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 2.8544775000000002,
#   'node': PhyloTree node '' (0x7f18f1fadeb),
#   'seq_no': 14,
#   'tree': 'Phy000CXV4_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 1.030109,
#   'node': PhyloTree node '' (0x7f18f1fb055),
#   'seq_no': 3,
#   'tree': 'Phy000CZZ3_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.699912,
#   'node': PhyloTree node '' (0x7f18f1fb05e),
#   'seq_no': 6,
#   'tree': 'Phy000CXHR_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.02383,
#   'node': PhyloTree node '' (0x7f18f1fb0d9),
#   'seq_no': 3,
#   'tree': 'Phy000CYSF_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.057456999999999994,
#   'node': PhyloTree node '' (0x7f18f1fb0be),
#   'seq_no': 5,
#   'tree': 'Phy000CYSF_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.39346799999999993,
#   'node': PhyloTree node '' (0x7f18f1fd52b),
#   'seq_no': 8,
#   'tree': 'Phy000CYJJ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.21559649999999997,
#   'node': PhyloTree node '' (0x7f18f1fd5a3),
#   'seq_no': 12,
#   'tree': 'Phy000CYMZ_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.1814395,
#   'node': PhyloTree node '' (0x7f18f1fd5e2),
#   'seq_no': 8,
#   'tree': 'Phy000CYMZ_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.8219815,
#   'node': PhyloTree node '' (0x7f18f1d40f1),
#   'seq_no': 8,
#   'tree': 'Phy000CZP0_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.803219,
#   'node': PhyloTree node '' (0x7f18f1d505b),
#   'seq_no': 11,
#   'tree': 'Phy000CXUN_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.371605,
#   'node': PhyloTree node '' (0x7f18f1d503a),
#   'seq_no': 3,
#   'tree': 'Phy000CXUN_YEAST'},
#  {'Normalising group': 'B',
#   'mrca_to_tip_median': 0.07078899999999999,
#   'node': PhyloTree node '' (0x7f18f1d3e2b),
#   'seq_no': 11,
#   'tree': 'Phy000CXY3_YEAST'},
#  {'Normalising group': 'A',
#   'mrca_to_tip_median': 0.0664265,
#   'node': PhyloTree node '' (0x7f18f1d3e6a),
#   'seq_no': 4,
#   'tree': 'Phy000CXY3_YEAST'}]
