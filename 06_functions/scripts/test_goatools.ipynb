# %%
import os
import goatools
import pandas as pd
import math

# %%
from goatools.obo_parser import GODag

if not os.path.exists('go-basic.obo'):
    # !wget http://geneontology.org/ontology/go-basic.obo
go = GODag('go-basic.obo', optional_attrs=['relationship'])
# Out:
# go-basic.obo: fmt(1.2) rel(2022-01-13) 47,158 Terms; optional_attrs(relationship)

# %%
ipsdf = pd.read_csv('../outputs/YARLI_013.tsv', sep='\t', header=None)

# %%
ipsdf
# Out:
#                    0                                 1    2            3   \
# 0    Phy000EZM9_YARLI  182489b69ecd13cc3c05f1e075e227f1  248  SUPERFAMILY
# 1    Phy000EZM9_YARLI  182489b69ecd13cc3c05f1e075e227f1  248       Gene3D
# 2    Phy000EZM9_YARLI  182489b69ecd13cc3c05f1e075e227f1  248  SUPERFAMILY
# 3    Phy000EZM9_YARLI  182489b69ecd13cc3c05f1e075e227f1  248       Gene3D
# 4    Phy000EZM9_YARLI  182489b69ecd13cc3c05f1e075e227f1  248         Pfam
# ..                ...                               ...  ...          ...
# 357  Phy000EZMD_YARLI  ef77229a7c5d235095abd905c9e6d709  663       PRINTS
# 358  Phy000EZMD_YARLI  ef77229a7c5d235095abd905c9e6d709  663       PRINTS
# 359  Phy000EZMD_YARLI  ef77229a7c5d235095abd905c9e6d709  663       PRINTS
# 360  Phy000EZMD_YARLI  ef77229a7c5d235095abd905c9e6d709  663       PRINTS
# 361  Phy000EZMD_YARLI  ef77229a7c5d235095abd905c9e6d709  663       Gene3D
#
#                     4                                         5    6    7   \
# 0             SSF55608                                       NaN   45  200
# 1     G3DSA:3.10.28.10                                       NaN  176  248
# 2             SSF55608                                       NaN  181  245
# 3     G3DSA:3.10.28.10                                       NaN   43  175
# 4              PF00961                    LAGLIDADG endonuclease  188  242
# ..                 ...                                       ...  ...  ...
# 357            PR01165  Cytochrome c oxidase subunit I signature   86  110
# 358            PR01165  Cytochrome c oxidase subunit I signature  286  301
# 359            PR01165  Cytochrome c oxidase subunit I signature    9   34
# 360            PR01165  Cytochrome c oxidase subunit I signature  345  363
# 361  G3DSA:1.20.210.10                                       NaN    1  377
#
#            8  9           10         11  \
# 0    2.01E-22  T  14-02-2022  IPR027434
# 1     6.4E-12  T  14-02-2022  IPR027434
# 2     2.92E-9  T  14-02-2022  IPR027434
# 3     1.1E-13  T  14-02-2022  IPR027434
# 4      1.1E-6  T  14-02-2022  IPR004860
# ..        ... ..         ...        ...
# 357  4.0E-108  T  14-02-2022  IPR000883
# 358  4.0E-108  T  14-02-2022  IPR000883
# 359  4.0E-108  T  14-02-2022  IPR000883
# 360  4.0E-108  T  14-02-2022  IPR000883
# 361  2.7E-154  T  14-02-2022  IPR036927
#
#                                                     12  \
# 0                                  Homing endonuclease
# 1                                  Homing endonuclease
# 2                                  Homing endonuclease
# 3                                  Homing endonuclease
# 4                       Homing endonuclease, LAGLIDADG
# ..                                                 ...
# 357                     Cytochrome c oxidase subunit I
# 358                     Cytochrome c oxidase subunit I
# 359                     Cytochrome c oxidase subunit I
# 360                     Cytochrome c oxidase subunit I
# 361  Cytochrome c oxidase-like, subunit I  superfamily
#
#                                                     13
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                           GO:0004519
# ..                                                 ...
# 357  GO:0004129|GO:0009060|GO:0016021|GO:0020037|GO...
# 358  GO:0004129|GO:0009060|GO:0016021|GO:0020037|GO...
# 359  GO:0004129|GO:0009060|GO:0016021|GO:0020037|GO...
# 360  GO:0004129|GO:0009060|GO:0016021|GO:0020037|GO...
# 361                                         GO:0055114
#
# [362 rows x 14 columns]

# %%
odfl = list()
for i, item in enumerate(list(ipsdf[13])):
    if isinstance(item, str):
        if '|' in item:
            item = item.split('|')
            for subitem in item:
                try:
                    goterm = go[subitem]
                    odfd = dict()
                    odfd['id'] = ipsdf[0][i]
                    odfd['eval'] = ipsdf[8][i]
                    odfd[goterm.namespace] = goterm.name
                    odfl.append(odfd)
                except KeyError:
                    continue
        else:
            try:
                goterm = go[item]
                odfd = dict()
                odfd['id'] = ipsdf[0][i]
                odfd['eval'] = ipsdf[8][i]
                odfd[goterm.namespace] = goterm.name
                odfl.append(odfd)
            except KeyError:
                continue

# %%
goterm.namespace
# Out:
# 'molecular_function'

# %%
def miau(l):
    s = ' / '.join(set([x for x in l if str(x) != 'nan']))
    return s

# %%
odf = pd.DataFrame(odfl)
odf = odf.groupby('id').agg(miau)

# %%
odf
# Out:
#                                                                eval  \
# id
# Phy000EZM7_YARLI                                             7.6E-7
# Phy000EZM8_YARLI                                            1.1E-41
# Phy000EZM9_YARLI                                             1.1E-6
# Phy000EZMA_YARLI                                     12.1 / 4.8E-16
# Phy000EZMB_YARLI      9.9E-20 / 1.6E-15 / 3.8E-10 / 14.384 / 1.1E-9
# Phy000EZMC_YARLI               2.3E-36 / 26.272 / 2.5E-18 / 9.5E-26
# Phy000EZMD_YARLI    9.0E-101 / 4.0E-108 / 1.3E-13 / 81.554 / 2.9E-9
# Phy000EZME_YARLI                2.0E-74 / 2.8E-8 / 51.189 / 3.8E-59
# Phy000EZMF_YARLI                     6.7E-14 / - / 2.0E-39 / 16.255
# Phy000EZMG_YARLI  - / 1.0E-66 / 0.0 / 36.617 / 40.872 / 4.8E-40 ...
# Phy000EZMH_YARLI       - / 6.0E-69 / 50.138 / 3.3E-86 / 8.88138E-20
# Phy000EZMI_YARLI                                                  -
# Phy000EZMK_YARLI                                  2.6E-42 / 9.2E-28
# Phy000EZML_YARLI                                  3.4E-39 / 4.0E-68
# Phy000EZMM_YARLI                         27.169 / 6.9E-37 / 3.6E-53
# Phy000EZMN_YARLI                                   2.2E-46 / 27.704
# Phy000EZMO_YARLI                              1.6E-56 / - / 3.4E-81
# Phy000EZMP_YARLI                      - / 4.5E-46 / 31.58 / 6.3E-46
# Phy000EZMQ_YARLI                   47.793 / 2.6E-120 / - / 6.7E-175
# Phy000EZMR_YARLI                   1.1E-181 / - / 1.3E-23 / 1.2E-29
# Phy000EZMS_YARLI  1.2E-72 / 2.0E-16 / - / 6.52907E-10 / 19.785 /...
# Phy000EZMT_YARLI                                         1.5E-6 / -
# Phy000EZMU_YARLI  0.018 / 2.2E-4 / - / 3.2E-4 / 3.2E-7 / 15.126 ...
# Phy000EZMV_YARLI  3.6E-46 / 2.2E-4 / - / 1.8E-7 / 8.5E-20 / 6.2E...
#
#                                                  molecular_function  \
# id
# Phy000EZM7_YARLI                              endonuclease activity
# Phy000EZM8_YARLI                              endonuclease activity
# Phy000EZM9_YARLI                              endonuclease activity
# Phy000EZMA_YARLI       heme binding / cytochrome-c oxidase activity
# Phy000EZMB_YARLI  heme binding / endonuclease activity / cytochr...
# Phy000EZMC_YARLI  heme binding / endonuclease activity / cytochr...
# Phy000EZMD_YARLI  heme binding / endonuclease activity / cytochr...
# Phy000EZME_YARLI  heme binding / endonuclease activity / cytochr...
# Phy000EZMF_YARLI  nucleic acid binding / aspartic-type endopepti...
# Phy000EZMG_YARLI  methylenetetrahydrofolate dehydrogenase (NADP+...
# Phy000EZMH_YARLI  protein serine/threonine kinase activity / ATP...
# Phy000EZMI_YARLI                            oxidoreductase activity
# Phy000EZMK_YARLI
# Phy000EZML_YARLI                 transmembrane transporter activity
# Phy000EZMM_YARLI                      GTP binding / GTPase activity
# Phy000EZMN_YARLI  oxidoreductase activity, acting on NAD(P)H / 4...
# Phy000EZMO_YARLI                            oxidoreductase activity
# Phy000EZMP_YARLI  oxidoreductase activity, acting on NAD(P)H / N...
# Phy000EZMQ_YARLI  oxidoreductase activity, acting on NAD(P)H / N...
# Phy000EZMR_YARLI  4 iron, 4 sulfur cluster binding / FMN binding...
# Phy000EZMS_YARLI  oxidoreductase activity / electron transfer ac...
# Phy000EZMT_YARLI         zinc ion binding / oxidoreductase activity
# Phy000EZMU_YARLI                               nucleic acid binding
# Phy000EZMV_YARLI  GTP binding / GTPase activity / signal recogni...
#
#                                             cellular_component  \
# id
# Phy000EZM7_YARLI
# Phy000EZM8_YARLI
# Phy000EZM9_YARLI
# Phy000EZMA_YARLI                integral component of membrane
# Phy000EZMB_YARLI                integral component of membrane
# Phy000EZMC_YARLI                integral component of membrane
# Phy000EZMD_YARLI                integral component of membrane
# Phy000EZME_YARLI                integral component of membrane
# Phy000EZMF_YARLI
# Phy000EZMG_YARLI
# Phy000EZMH_YARLI
# Phy000EZMI_YARLI
# Phy000EZMK_YARLI
# Phy000EZML_YARLI                  mitochondrial inner membrane
# Phy000EZMM_YARLI
# Phy000EZMN_YARLI                                      membrane
# Phy000EZMO_YARLI
# Phy000EZMP_YARLI
# Phy000EZMQ_YARLI
# Phy000EZMR_YARLI
# Phy000EZMS_YARLI                                      membrane
# Phy000EZMT_YARLI
# Phy000EZMU_YARLI
# Phy000EZMV_YARLI  signal recognition particle receptor complex
#
#                                                  biological_process
# id
# Phy000EZM7_YARLI
# Phy000EZM8_YARLI
# Phy000EZM9_YARLI
# Phy000EZMA_YARLI                                aerobic respiration
# Phy000EZMB_YARLI                                aerobic respiration
# Phy000EZMC_YARLI                                aerobic respiration
# Phy000EZMD_YARLI                                aerobic respiration
# Phy000EZME_YARLI                                aerobic respiration
# Phy000EZMF_YARLI                      proteolysis / DNA integration
# Phy000EZMG_YARLI
# Phy000EZMH_YARLI                            protein phosphorylation
# Phy000EZMI_YARLI
# Phy000EZMK_YARLI  lipid metabolic process / lipid catabolic process
# Phy000EZML_YARLI                            transmembrane transport
# Phy000EZMM_YARLI          small GTPase mediated signal transduction
# Phy000EZMN_YARLI
# Phy000EZMO_YARLI
# Phy000EZMP_YARLI
# Phy000EZMQ_YARLI
# Phy000EZMR_YARLI
# Phy000EZMS_YARLI           ATP synthesis coupled electron transport
# Phy000EZMT_YARLI
# Phy000EZMU_YARLI
# Phy000EZMV_YARLI  SRP-dependent cotranslational protein targetin...
